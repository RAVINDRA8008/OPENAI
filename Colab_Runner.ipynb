# %% [markdown]
# # Parameter Golf - A100 Colab Runner
# This notebook is pre-configured to train our Universal Transformer SOTA script directly from your GitHub repo.

# %%
# Clone your repository
# !git clone https://github.com/RAVINDRA8008/OPENAI.git
# %cd OPENAI/parameter-golf
# !pip install mlx numpy sentencepiece huggingface-hub datasets tqdm zlib
# Out:
# Cloning into 'OPENAI'...
# remote: Enumerating objects: 193, done.
# remote: Counting objects: 100% (193/193), done.
# remote: Compressing objects: 100% (129/129), done.
# remote: Total 193 (delta 60), reused 193 (delta 60), pack-reused 0 (from 0)
# Receiving objects: 100% (193/193), 1.01 MiB | 8.13 MiB/s, done.
# Resolving deltas: 100% (60/60), done.
# /content/OPENAI/parameter-golf
# ...
# ERROR: Could not find a version that satisfies the requirement zlib (from versions: none)
# ERROR: No matching distribution found for zlib

# %%
# Download Dataset
# !python3 data/cached_challenge_fineweb.py --variant sp1024
# Out:
# manifest.json: 1.93kB [00:00, 10.6MB/s]
# datasets/datasets/fineweb10B_sp1024/fine(…): 100% 124M/124M [00:01<00:00, 77.9MB/s]
# datasets/datasets/fineweb10B_sp1024/fine(…): 100% 200M/200M [00:01<00:00, 129MB/s]
# datasets/datasets/fineweb10B_sp1024/fine(…): 100% 200M/200M [00:01<00:00, 116MB/s]
# datasets/datasets/fineweb10B_sp1024/fine(…): 100% 200M/200M [00:01<00:00, 113MB/s]
# datasets/datasets/fineweb10B_sp1024/fine(…): 100% 200M/200M [00:01<00:00, 124MB/s]
# datasets/datasets/fineweb10B_sp1024/fine(…): 100% 200M/200M [00:01<00:00, 122MB/s]
# datasets/datasets/fineweb10B_sp1024/fine(…): 100% 200M/200M [00:01<00:00, 116MB/s]
# datasets/datasets/fineweb10B_sp1024/fine(…): 100% 200M/200M [00:01<00:00, 119MB/s]
# datasets/datasets/fineweb10B_sp1024/fine(…): 100% 200M/200M [00:01<00:00, 128MB/s]
# datasets/datasets/fineweb10B_sp1024/fine(…): 100% 200M/200M [00:01<00:00, 102MB/s]
# datasets/datasets/fineweb10B_sp1024/fine(…): 100% 200M/200M [00:01<00:00, 130MB/s]
# ...

# %%
# LAUNCH TRAINING!
# The custom script is already in the repository at records/track_10min_16mb/our_submission/train_gpt.py
# !RUN_ID=a100_sota_run DATA_PATH=./data/datasets/fineweb10B_sp1024/ TOKENIZER_PATH=./data/tokenizers/fineweb_1024_bpe.model VOCAB_SIZE=1024 torchrun --standalone --nproc_per_node=1 records/track_10min_16mb/our_submission/train_gpt.py
# Out:
# logs/a100_sota_run.txt
# val_bpb:enabled tokenizer_kind=sentencepiece tokenizer_path=./data/tokenizers/fineweb_1024_bpe.model
# train_loader:dataset:fineweb10B_sp1024 train_shards:80
# val_loader:shards pattern=./data/datasets/fineweb10B_sp1024/fineweb_val_*.bin tokens:62021632
# model_params:9998352
# world_size:1 grad_accum_steps:8
# sdp_backends:cudnn=False flash=True mem_efficient=False math=False
# attention_mode:gqa num_heads:16 num_kv_heads:4
# tie_embeddings:True embed_lr:0.05 head_lr:0.0 matrix_lr:0.04 scalar_lr:0.04
# train_batch_tokens:524288 train_seq_len:1024 iterations:15000 warmup_steps:20 max_wallclock_seconds:36000.000
# seed:1337
# warmup_step:1/20
# warmup_step:2/20
# warmup_step:3/20
# warmup_step:4/20
# warmup_step:5/20
# warmup_step:6/20
# warmup_step:7/20
# warmup_step:8/20
# warmup_step:9/20
# warmup_step:10/20
# warmup_step:11/20
# warmup_step:12/20
# warmup_step:13/20
# warmup_step:14/20
# warmup_step:15/20
# warmup_step:16/20
# warmup_step:17/20
# ...
